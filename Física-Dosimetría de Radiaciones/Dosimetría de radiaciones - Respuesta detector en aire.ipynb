# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Variables:

E = [4.00e-03,5.00e-03,6.00e-03,8.00e-03,1.00e-02,1.50e-02,2.00e-02,3.00e-02,4.00e-02,5.00e-02,6.00e-02,8.00e-02,1.00e-01,1.50e-01,2.00e-01,3.00e-01,4.00e-01,5.00e-01,6.00e-01,8.00e-01,1.00e-00,1.50e-00,2.00e-00,3.00e-00,4.00e-00,5.00e-00,6.00e-00,8.00e-00]

mu_en_60Co = 2.434e-02

mu_en_aire = np.array([7.636e+01,3.931e+01,2.270e+01,9.446e+00,4.742e+00,1.334e+00,5.389e-01,1.537e-01,6.833e-02,4.098e-02,3.041e-02,2.407e-02,2.325e-02,2.496e-02,2.672e-02,2.872e-02,2.949e-02,2.966e-02,2.953e-02,2.882e-02,2.789e-02,2.666e-02,2.345e-02,2.057e-02,1.870e-02,1.74e-02,1.647e-02,1.525e-02])

mu_en_silicio = np.array([4.427e+02,2.400e+02,1.439e+02,6.313e+01,3.289e+01,9.794,4.076e+0,1.164e+00,4.782e-01,2.43e-01,1.434e-01,6.896e-02,4.513e-02,3.086e-02,2.905e-02,2.932e-02,2.968e-02,2.971e-02,2.951e-02,2.875e-02,2.778e-02,2.535e-02,2.345e-02,2.101e-02,1.963e-02,1.878e-02,1.827e-02,1.773e-02])

mu_en_carbono = np.array([3.723e+01,1.866e+01,1.054e+01,4.242e+00,2.078e+00,5.627e-01,2.238e-01,6.614e-02,3.343e-02,2.397e-02,2.098e-02,2.037e-02,2.147e-02,2.449e-02,2.655e-02,2.870e-02,2.950e-02,2.969e-02,2.956e-02,2.885e-02,2.792e-02,2.551e-02,2.345e-02,2.048e-02,1.849e-02,1.71e-02,1.607e-02,1.468e-02])

mu_en_pmma = np.array([5.181e+01,2.627e+01,1.498e+01,6.114e+00,3.026e+00,8.324e-01,3.328e-01,9.645e-02,4.599e-02,3.067e-02,2.53e-02,2.302e-02,2.368e-02,2.657e-02,2.872e-02,3.099e-02,3.185e-02,3.206e-02,3.191e-02,3.116e-02,3.015e-02,2.755e-02,2.533e-02,2.210e-02,1.995e-02,1.843e-02,1.721e-02,1.579e-02])

mu_en_polietileno = np.array([3.189e+01,1.598e+01,9.032e+0,3.635e+00,1.781e+00,4.834e-01,1.936e-01,5.932e-02,3.196e-02,2.442e-02,2.236e-02,2.265e-02,2.423e-02,2.789e-02,3.029e-02,3.276e-02,3.368e-02,3.39e-02,3.375e-02,3.295e-02,3.19e-02,2.914e-02,2.677e-02,2.328e-02,2.091e-02,1.921e-02,1.794e-02,1.62e-02])

mu_en_LiF = np.array([9.188e+01,4.742e+01,2.742e+01,1.142e+01,5.733e+00,1.612e+00,6.494e-01,1.826e-01,7.89e-02,4.541e-02,3.223e-02,2.385e-02,2.229e-02,2.332e-02,2.484e-02,2.663e-02,2.734e-02,2.749e-02,2.736e-02,2.671e-02,2.585e-02,2.361e-02,2.173e-02,1.907e-02,1.733e-02,1.614e-02,1.528e-02,1.414e-02])

# %%
R_aire = (mu_en_aire/mu_en_aire)/mu_en_60Co

R_silicio = (mu_en_silicio/mu_en_aire)/mu_en_60Co

R_carbono = (mu_en_carbono/mu_en_aire)/mu_en_60Co

R_pmma = (mu_en_pmma/mu_en_aire)/mu_en_60Co

R_polietileno = (mu_en_polietileno/mu_en_aire)/mu_en_60Co

R_LiF = (mu_en_LiF/mu_en_aire)/mu_en_60Co

# %%
# Graficar en escala log-log
plt.figure(figsize=(10, 6))
plt.loglog(E, R_aire, label="Aire", linestyle='--',linewidth=2.5)
plt.loglog(E, R_silicio, label="Silicio", linestyle='-',linewidth=2.5)
plt.loglog(E, R_carbono, label="Carbono", linestyle='-',linewidth=2.5)
plt.loglog(E, R_pmma, label="PMMA", linestyle='-',linewidth=2.5)
plt.loglog(E, R_polietileno, label="Polietileno", linestyle='-',linewidth=2.5)
plt.loglog(E, R_LiF, label="LiF", linestyle='-',linewidth=2.5)

# Configuración de la gráfica
plt.title("Curva de dependencia energética con referencia a Cobalto-60", fontsize=17)
plt.xlabel("Energía [MeV]", fontsize=16)
plt.ylabel("Respuesta del detector en aire", fontsize=16)
plt.axis('tight')
plt.legend(fontsize=14, loc="best")
plt.grid(visible=True, which="both", linestyle="--", linewidth=1.2)
plt.xlim(4.00e-03, 8)
plt.tight_layout()

# Mostrar gráfica
plt.show()
